# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# 10 - Stiff multiscale time stepping\n",
        "\n",
        "We inspect stiffness proxies on a random linear system matrix.\n"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import tensorflow as tf\n",
        "from tig.core.random import Rng\n",
        "from tig.diffeq.stiff import spectral_radius_proxy, stiffness_ratio_proxy\n",
        "\n",
        "tf.keras.backend.set_floatx(\"float64\")\n",
        "tf.config.run_functions_eagerly(True)\n",
        "\n",
        "rng = Rng(seed=0)\n",
        "A = rng.normal((32, 32), dtype=tf.float64)\n",
        "rho = spectral_radius_proxy(A)\n",
        "ratio = stiffness_ratio_proxy(A, ridge=1e-12)\n",
        "\n",
        "print(\"spectral radius proxy:\", float(rho.numpy()))\n",
        "print(\"stiffness ratio proxy:\", float(ratio.numpy()))\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.x"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
