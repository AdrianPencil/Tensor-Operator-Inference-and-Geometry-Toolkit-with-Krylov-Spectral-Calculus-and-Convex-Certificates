# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# 08 - SDP relaxations and certificates\n",
        "\n",
        "We focus on **certificate checks** (PSD, gap proxy) rather than a full SDP solver.\n"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import tensorflow as tf\n",
        "from tig.core.random import Rng\n",
        "from tig.convex.certificates import is_psd, primal_dual_gap\n",
        "\n",
        "tf.keras.backend.set_floatx(\"float64\")\n",
        "tf.config.run_functions_eagerly(True)\n",
        "\n",
        "rng = Rng(seed=0)\n",
        "m = rng.normal((12, 12), dtype=tf.float64)\n",
        "X = tf.transpose(m) @ m\n",
        "\n",
        "print(\"PSD:\", bool(is_psd(X, tol=1e-10).numpy()))\n",
        "print(\"gap:\", primal_dual_gap(primal_value=2.0, dual_value=1.7))\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.x"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
