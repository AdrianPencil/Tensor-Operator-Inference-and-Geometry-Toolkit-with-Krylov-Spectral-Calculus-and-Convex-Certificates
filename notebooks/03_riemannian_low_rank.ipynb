# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# 03 - Riemannian low-rank geometry (Stiefel)\n",
        "\n",
        "We demonstrate Stiefel retraction behavior: enforce `XᵀX = 𝕀` after a step.\n"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import tensorflow as tf\n",
        "from tig.core.random import Rng\n",
        "from tig.geometry.stiefel import retract_qr\n",
        "\n",
        "tf.keras.backend.set_floatx(\"float64\")\n",
        "tf.config.run_functions_eagerly(True)\n",
        "\n",
        "rng = Rng(seed=0)\n",
        "X = rng.normal((64, 8), dtype=tf.float64)\n",
        "U = rng.normal((64, 8), dtype=tf.float64)\n",
        "\n",
        "Y = retract_qr(X, U)\n",
        "G = tf.transpose(Y) @ Y\n",
        "err = tf.linalg.norm(G - tf.eye(8, dtype=tf.float64))\n",
        "print(\"||Y^T Y - I||_F:\", float(err.numpy()))\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.x"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
